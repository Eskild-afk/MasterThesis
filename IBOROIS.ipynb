# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import pandas as pd
import numpy as np


EONIA = pd.read_csv('EONIARATE.csv')
EONIA.columns = ['Date', 'EONIA']
# EONIA = EONIA.loc[np.where(EONIA['EONIA']!='.')]
EONIA['Date'] = pd.to_datetime(EONIA['Date'])
EONIA = EONIA.iloc[np.where(EONIA['Date']>=pd.to_datetime('2000-01-01'))]
EONIA = EONIA.iloc[np.where(EONIA['Date']<pd.to_datetime('2022-01-01'))]
# EONIA['EONIA'] = pd.to_numeric(EONIA['EONIA'])

EURIBOR = pd.read_csv('EURIBOR.csv')
EURIBOR.columns = ['Date', 'EURIBOR']
EURIBOR['Date'] = pd.to_datetime(EURIBOR['Date'])
EURIBOR = EURIBOR.iloc[np.where(EURIBOR['Date']>=pd.to_datetime('2000-01-01'))]
EURIBOR = EURIBOR.iloc[np.where(EURIBOR['Date']<pd.to_datetime('2022-01-01'))]
# merged = pd.merge(EURIBOR, EONIA, on='Date', how='left').dropna()

# merged['spread'] = abs(np.array(merged['EURIBOR']) - np.array(merged['EONIA']))
# merged['Date'] = pd.to_datetime(merged['Date'])
# EONIA.head(), EURIBOR.head(), merged.head()

# %%
EONIA[::-1]
# Out:
#           Date    EONIA
# 263 2000-01-01  3.04286
# 262 2000-02-01  3.27571
# 261 2000-03-01  3.51043
# 260 2000-04-01  3.68500
# 259 2000-05-01  3.92000
# ..         ...      ...
# 4   2021-08-01 -0.48291
# 3   2021-09-01 -0.48505
# 2   2021-10-01 -0.48557
# 1   2021-11-01 -0.48800
# 0   2021-12-01 -0.49222
#
# [264 rows x 2 columns]

# %%
sns.lineplot(x='Date', y='spread', data=merged)
# Out:
# <Axes: xlabel='Date', ylabel='spread'>

# %%
A=np.random.normal(0,1,100000000)

# %%
from scipy.stats import norm
from scipy.special import erfinv
U=np.random.uniform(0,2,100000000)
B=np.sqrt(2)*erfinv(U-1)

# %%
sns.displot(A[0:100000], kde=True, rug=False, color = 'blue')
sns.displot(B[0:100000], kde=True, rug=False, color = 'red')

# %%
for i in range(np.power(10,5)):
    Z=np.random.normal(0,1,size=365*15)

# %%
np.max()
# Out:
# 30.0

# %%
np.arange(0,30+1/,0.5)
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ,
#         5.5,  6. ,  6.5,  7. ,  7.5,  8. ,  8.5,  9. ,  9.5, 10. , 10.5,
#        11. , 11.5, 12. , 12.5, 13. , 13.5, 14. , 14.5, 15. , 15.5, 16. ,
#        16.5, 17. , 17.5, 18. , 18.5, 19. , 19.5, 20. , 20.5, 21. , 21.5,
#        22. , 22.5, 23. , 23.5, 24. , 24.5, 25. , 25.5, 26. , 26.5, 27. ,
#        27.5, 28. , 28.5, 29. , 29.5, 30. , 30.5])

# %%
dt=1/365
for i in range(np.power(10,5)):
    n = Z[i*int(1/dt):(i+1)*int(1/dt)]
    S = 100
    for z in n:
        S += 0.03*S*dt + 0.3*S*np.sqrt(dt)*z

# %%
for i in range(np.power(10,5)):
    S = 100
    for z in n:
        S += 0.03*S*dt + 0.3*S*np.sqrt(dt)*np.random.normal(0,1)

# %%
for i in range(np.power(10,5)):
    n = np.random.normal(0,1,size=int(1/dt))
    S = 100
    for z in n:
        S += 0.03*S*dt + 0.3*S*np.sqrt(dt)*z

# %%
for i in range(int(np.power(10,6)*365)):
    print(Z[i]*2, i, end='\r')

# %%
for i in range(int(np.power(10,6)*365)):
    np.random.normal(0,1)

# %%
sns.lineplot(x=np.linspace(0,1,1000), y=[np.sqrt(2)*erfinv(2*x-1) for x in np.linspace(0,1,1000)])
sns.lineplot(x=np.linspace(0,1,1000), y=[-np.sqrt(np.log(1/(x**2))-np.log(np.log(1/(x**2)))-np.log(2*np.pi)) for x in np.linspace(0,1,1000)])
# Out:
# C:\Users\Shark\AppData\Local\Temp\ipykernel_27712\2028322478.py:2: RuntimeWarning: divide by zero encountered in scalar divide
#   sns.lineplot(x=np.linspace(0,1,1000), y=[-np.sqrt(np.log(1/(x**2))-np.log(np.log(1/(x**2)))-np.log(2*np.pi)) for x in np.linspace(0,1,1000)])
# C:\Users\Shark\AppData\Local\Temp\ipykernel_27712\2028322478.py:2: RuntimeWarning: invalid value encountered in scalar subtract
#   sns.lineplot(x=np.linspace(0,1,1000), y=[-np.sqrt(np.log(1/(x**2))-np.log(np.log(1/(x**2)))-np.log(2*np.pi)) for x in np.linspace(0,1,1000)])
# C:\Users\Shark\AppData\Local\Temp\ipykernel_27712\2028322478.py:2: RuntimeWarning: invalid value encountered in sqrt
#   sns.lineplot(x=np.linspace(0,1,1000), y=[-np.sqrt(np.log(1/(x**2))-np.log(np.log(1/(x**2)))-np.log(2*np.pi)) for x in np.linspace(0,1,1000)])
# C:\Users\Shark\AppData\Local\Temp\ipykernel_27712\2028322478.py:2: RuntimeWarning: divide by zero encountered in log
# ...
